# %% [markdown]
# # Native Image Transformation

# %%
import os
import warnings
import cv2
import matplotlib.pyplot as plt
import matplotlib.style as style
import numpy as np
import pandas as pd
from PIL import Image
from tensorflow.keras.preprocessing import image as image_utils
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import pickle

# %matplotlib inline
style.use('seaborn-whitegrid')
warnings.filterwarnings(action='once')

# %%
with open('X_data.pkl', 'rb') as f:
    X_data = pickle.load(f)

# %%
# The goal is to approximate native webcam / input camera image to the following:
plt.imshow(X_data_sil[0])

# %%
frame = cv2.imread('fist.png', cv2.IMREAD_GRAYSCALE)

plt.imshow(frame)

# %%
frame = cv2.flip(frame, 1)

# %%
plt.imshow(frame)

# %%
frame = cv2.GaussianBlur(frame, (41, 41), 0)

# %%
plt.imshow(frame)

# %%
ret, frame = cv2.threshold(frame, 150, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# %%
plt.imshow(frame)

# %%
frame = np.stack((frame,)*3, axis=-1)

# %%
plt.imshow(frame)

# %%
frame = cv2.resize(frame, (224, 224))

# %%
plt.imshow(frame)

# %%
frame = frame.reshape(1, 224, 224, 3)

# %%
plt.imshow(frame[0])

# %%
frame = np.array(frame, dtype='float32')

# %%
plt.imshow(frame[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
frame /= 255 # Normalize image

# %%
plt.imshow(frame[0])

# %% [markdown]
# # Compiled function with some variations

# %%
# New function

def the_function(path):
    frame = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    frame = cv2.flip(frame, 1)
    frame = cv2.GaussianBlur(frame, (41, 41), 0)
    ret, frame = cv2.threshold(frame, 150, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    frame = np.stack((frame,)*3, axis=-1)
    frame = cv2.resize(frame, (224, 224))
    frame = frame.reshape(1, 224, 224, 3)
    frame = np.array(frame, dtype='float32')
    frame /= 255 # Normalize image
    plt.imshow(frame[0])

# %%
# New function

def the_function(path):
    frame = cv2.imread(path)
    frame = cv2.flip(frame, 1)
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    frame = cv2.GaussianBlur(frame, (41, 41), 0)
    ret, frame = cv2.threshold(frame, 150, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    frame = np.stack((frame,)*3, axis=-1)
    frame = cv2.resize(frame, (224, 224))
    frame = frame.reshape(1, 224, 224, 3)
    frame = np.array(frame, dtype='float32')
    frame /= 255 # Normalize image
    plt.imshow(frame[0])

# %%
# New function

def the_function(path):
    frame = cv2.imread(path, cv2.IMREAD_COLOR)
    frame = cv2.flip(frame, 1)
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    frame = cv2.GaussianBlur(frame, (41, 41), 0)
    ret, frame = cv2.threshold(frame, 150, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    frame = np.stack((frame,)*3, axis=-1)
    frame = cv2.resize(frame, (224, 224))
    frame = frame.reshape(1, 224, 224, 3)
    frame = np.array(frame, dtype='float32')
    frame /= 255 # Normalize image
    plt.imshow(frame[0])
